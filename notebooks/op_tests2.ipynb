# %%
from imports import *
from matplotlib.dates import DateFormatter
import matplotlib.dates as mdates
import datetime

# %%
t = np.arange(pd.Timestamp(2020,1,13),pd.Timestamp(2020,1,17),pd.Timedelta(hours=1)).astype(pd.Timestamp)
fig, (axr1,axr2) = plt.subplots(ncols = 2, nrows=2, figsize=(36,8))

sd1 = Step(start=datetime.datetime(2020,1,14,10,15),end=datetime.datetime(2020,1,16,12,1),weight=-2)

axr1[0].step(t,sd1(t))
axr1[1].step(t,(sd1*sd1)(t))
print(sd1**2)
print(sd1*sd1)
print((sd1**2)==(sd1*sd1))
# Out:
# 2020-01-14 10:15:00:4.0,
# 2020-01-16 12:01:00:0.0
# 2020-01-14 10:15:00:4.0,
# 2020-01-16 12:01:00:0.0
# True

# %%
sdd = Step(start=30,end=55.8,weight=-2)
sdd.plot()
