# %%
from imports import *
import staircase as sc
# %matplotlib inline
import operator
import warnings
warnings.filterwarnings("ignore")

# %%
s = Steps(start=pd.Timestamp(2020,1,2),end=pd.Timestamp(2020,1,5),weight=3.0)
s1 = Steps(end=50,weight=1.5)

ax = s.plot()
s.smooth_plot(ax=ax,smooth_factor=10**3,color='g')
s1.plot()
# Out:
# <AxesSubplot:>
